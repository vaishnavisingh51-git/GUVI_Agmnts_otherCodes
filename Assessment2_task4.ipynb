# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavisingh51-git/GUVI_Agmnts_otherCodes/blob/main/Assessment2_task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/content/college_1.csv")
df2=pd.read_csv("/content/college_2.csv")

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df1.shape
# Out:
# (84, 7)

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df2.shape
# Out:
# (35, 9)

# %%
data= pd.merge(df1, df2,on='Name', how='outer')
data.head(10)
# Out:
#                    Name  python_x  mysql_x  Previous Geekions_x  \
# 0             A.Dharani      82.0     20.0              24500.0
# 1           V.JEEVITHA       82.0     20.0              21740.0
# 2           HEMAVATHI.R     100.0    100.0              19680.0
# 3           Mugunthan S     100.0     47.0              10610.0
# 4           Sathammai.S     100.0      8.0               8980.0
# 5          NIVEESHWAR S     100.0      0.0               8200.0
# 6         KALAIARASAN K      85.0     47.0               7750.0
# 7  MOHAMED ZUBAIR AHMED      82.0      4.0               7020.0
# 8            J.SUGANTHI      27.0     50.0               5860.0
# 9          thamizhpaana      29.0      0.0               5500.0
#
#    CodeKata Score_x                               Department_x  Rising_x  \
# 0           24500.0           Computer Science and Engineering       0.0
# 1           21740.0           Computer Science and Engineering       0.0
# ...

# %%
data.shape
# Out:
# (119, 15)

# %% [markdown]
# Alternate Method

# %%
data1=df1.append(df2)
data1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
data1.shape
# Out:
# (119, 9)

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# For college_1

# %%
Exceeded=df1[df1['CodeKata Score']>15000]
Exceeded.to_csv('Exceeded expectations.csv')
x=pd.read_csv('Exceeded expectations.csv')
x.head()
# Out:
#    Unnamed: 0         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           0    A.Dharani    82.0   20.0              24500           24500
# 1           1  V.JEEVITHA     82.0   20.0              21740           21740
# 2           2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %% [markdown]
# For college_2

# %%
Exceeded2=df2[df2['CodeKata Score']>15000]
Exceeded2.to_csv('Exceeded expectations_college2.csv')
y=pd.read_csv('Exceeded expectations_college2.csv')
y.head()
# Out:
#    Unnamed: 0           Name  python  python_en  mysql  \
# 0           0  ASHOK KUMAR K     100          0     31
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                       9              19400           19400
#
#                                Department  Rising
# 0  Electronics and Electrical Engineering       0

# %% [markdown]
# Combined Result

# %%
Exceeded_all=data1[data1['CodeKata Score']>15000]
Exceeded_all.to_csv('Exceeded expectations_combined.csv',index=False)
z=pd.read_csv('Exceeded expectations_combined.csv')
z.head()
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 3  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# For college_1

# %%
Reached1 = df1[(df1['CodeKata Score'] > 10000) & (df1['CodeKata Score'] < 15000) ]
Reached1.to_csv('Reached_expectations1.csv')
a=pd.read_csv('Reached_expectations1.csv')
a.head()
# Out:
#    Unnamed: 0         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           3  Mugunthan S   100.0   47.0              10610           10610
#
#                          Department  Rising
# 0  Computer Science and Engineering       0

# %% [markdown]
# For college_2

# %%
Reached2 = df2[(df2['CodeKata Score'] > 10000) & (df2['CodeKata Score'] < 15000) ]
Reached2.to_csv('Reached_expectations2.csv')
b=pd.read_csv('Reached_expectations2.csv')
b.head()
# Out:
#    Unnamed: 0               Name  python  python_en  mysql  \
# 0           1            Chandru       0         20      0
# 1           2  Ganesh Ramkumar R      -1         55     24
# 2           3    Bodipudi Harini      -1          0     35
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                       0              14150           14490
# 1                       6               8790           10790
# 2                      -1              10040           10040
#
#                                   Department  Rising
# 0           Computer Science and Engineering     340
# 1           Computer Science and Engineering    2000
# 2  Electronics and Communication Engineering       0

# %% [markdown]
# Combined Result

# %%
Reached= data1[(data1['CodeKata Score'] > 10000) & (data1['CodeKata Score'] < 15000) ]
Reached.to_csv('Reached_expectations.csv',index=False)
c=pd.read_csv('Reached_expectations.csv')
c.head()
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# For College_1

# %%
Improve1 = df1[(df1['CodeKata Score'] > 7000) & (df1['CodeKata Score'] < 10000) ]
Improve1.to_csv('Needs_Improvement1.csv')
d=pd.read_csv('Needs_Improvement1.csv')
d.head()
# Out:
#    Unnamed: 0                  Name  python  mysql  Previous Geekions  \
# 0           4           Sathammai.S   100.0    8.0               8980
# 1           5          NIVEESHWAR S   100.0    0.0               8200
# 2           6         KALAIARASAN K    85.0   47.0               7750
# 3           7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020
#
#    CodeKata Score                                 Department  Rising
# 0            8980           Computer Science and Engineering       0
# 1            8200           Computer Science and Engineering       0
# 2            7880  Electronics and Communication Engineering     130
# 3            7020           Computer Science and Engineering       0

# %% [markdown]
# For college_2

# %%
Improve2 = df2[(df2['CodeKata Score'] > 7000) & (df2['CodeKata Score'] < 10000) ]
Improve2.to_csv('Needs_Improvement2.csv')
e=pd.read_csv('Needs_Improvement2.csv')
e.head()
# Out:
#    Unnamed: 0                    Name  python  python_en  mysql  \
# 0           4               VIINU V P      -1        100     24
# 1           5              Poojitha Y       0         78     35
# 2           6  Gowtham Chandrasekaran      -1          0      0
# 3           7               Gowtham R      -1         60      4
# 4           8                shifak N      58          0      0
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                      -1               9150            9150
# 1                       0               7210            8970
# 2                       3               7250            8950
# 3                       6               8650            8650
# 4                       0               5180            8320
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering    1760
# ...

# %% [markdown]
# Combined Results

# %%
Improve = data1[(data1['CodeKata Score'] > 7000) & (data1['CodeKata Score'] < 10000) ]
Improve.to_csv('Needs_Improvement.csv')
f=pd.read_csv('Needs_Improvement.csv')
f.head()
# Out:
#    Unnamed: 0                  Name  python  mysql  Previous Geekions  \
# 0           4           Sathammai.S   100.0    8.0               8980
# 1           5          NIVEESHWAR S   100.0    0.0               8200
# 2           6         KALAIARASAN K    85.0   47.0               7750
# 3           7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 4           4             VIINU V P    -1.0   24.0               9150
#
#    CodeKata Score                                 Department  Rising  \
# 0            8980           Computer Science and Engineering       0
# 1            8200           Computer Science and Engineering       0
# 2            7880  Electronics and Communication Engineering     130
# 3            7020           Computer Science and Engineering       0
# 4            9150     Electronics and Electrical Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1        NaN                     NaN
# ...

# %%
f.shape
# Out:
# (18, 10)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %% [markdown]
# For college_1

# %%
Unsatisfactory1=df1[df1['CodeKata Score']<7000]
Unsatisfactory1.to_csv('Unsatisfactory1.csv')
g=pd.read_csv('Unsatisfactory1.csv')
g.head()
# Out:
#    Unnamed: 0             Name  python  mysql  Previous Geekions  \
# 0           8       J.SUGANTHI    27.0  50.00               5860
# 1           9     thamizhpaana    29.0   0.00               5500
# 2          10  Iyappan Samiraj    50.0  24.00               5400
# 3          11     Ponniyamma.R   100.0  11.25               5380
# 4          12        SABAPATHI   100.0   0.00               5280
#
#    CodeKata Score                                 Department  Rising
# 0            5860  Electronics and Communication Engineering       0
# 1            5500           Computer Science and Engineering       0
# 2            5400  Electronics and Communication Engineering       0
# 3            5380           Computer Science and Engineering       0
# 4            5280           Computer Science and Engineering       0

# %% [markdown]
# For college_2

# %%
Unsatisfactory2=df2[df2['CodeKata Score']<7000]
Unsatisfactory2.to_csv('Unsatisfactory2.csv')
h=pd.read_csv('Unsatisfactory2.csv')
h.head()
# Out:
#    Unnamed: 0            Name  python  python_en  mysql  \
# 0          18  Narasimhan Y L      -1         -1      0
# 1          19    Leelakrishna      -1          6      4
# 2          20  PremsagarReddy      -1         20      0
# 3          21       pradeeban      16         20     24
# 4          22     santhoshini      -1         43      0
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                       0               4800            6800
# 1                       0               5300            6640
# 2                       0               5290            6290
# 3                       0               6060            6090
# 4                       0               3910            5740
#
#                          Department  Rising
# 0  Computer Science and Engineering    2000
# 1  Computer Science and Engineering    1340
# 2  Computer Science and Engineering    1000
# 3  Computer Science and Engineering      30
# ...

# %% [markdown]
# Combined Result

# %%
Unsatisfactory=data1[data1['CodeKata Score']<7000]
Unsatisfactory.to_csv('Unsatisfactory.csv')
i=pd.read_csv('Unsatisfactory.csv')
i.head()
# Out:
#    Unnamed: 0             Name  python  mysql  Previous Geekions  \
# 0           8       J.SUGANTHI    27.0  50.00               5860
# 1           9     thamizhpaana    29.0   0.00               5500
# 2          10  Iyappan Samiraj    50.0  24.00               5400
# 3          11     Ponniyamma.R   100.0  11.25               5380
# 4          12        SABAPATHI   100.0   0.00               5280
#
#    CodeKata Score                                 Department  Rising  \
# 0            5860  Electronics and Communication Engineering       0
# 1            5500           Computer Science and Engineering       0
# 2            5400  Electronics and Communication Engineering       0
# 3            5380           Computer Science and Engineering       0
# 4            5280           Computer Science and Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# ...

# %%
i.shape
# Out:
# (93, 10)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %% [markdown]
# For college_1

# %%
previousweekgeekions=(df1['Previous Geekions'].sum())/len(df1['Previous Geekions'])
previousweekgeekions1=df1['Previous Geekions'].mean()
CodeKataScore=df1['CodeKata Score'].mean()
print("Average of previous week geekions : ",previousweekgeekions1)
print("Average of this week geekions : ",CodeKataScore)
# Out:
# Average of previous week geekions :  2904.5238095238096
# Average of this week geekions :  2906.0714285714284

# %% [markdown]
# For college_2

# %%
previousweekgeekions=df2['Previous Geekions'].mean()
CodeKataScore=df2['CodeKata Score'].mean()
print("Average of previous week geekions : ",previousweekgeekions)
print("Average of this week geekions : ",CodeKataScore)
# Out:
# Average of previous week geekions :  6093.142857142857
# Average of this week geekions :  6801.428571428572

# %% [markdown]
# Combined Result

# %%
previousweekgeekions=data1['Previous Geekions'].mean()
CodeKataScore=data1['CodeKata Score'].mean()
print("Average of previous week geekions : ",previousweekgeekions)
print("Average of this week geekions : ",CodeKataScore)
# Out:
# Average of previous week geekions :  3842.3529411764707
# Average of this week geekions :  4051.764705882353

# %% [markdown]
# ###### No of students participated

# %% [markdown]
# No of students participated 119

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# For college_1

# %%
python1=df1['python'].mean()
my_sql1=df1['mysql'].mean()
print("Average completion of python course  : ",python1)
print("Average completion of my_sql course  : ",my_sql1)
# Out:
# Average completion of python course  :  73.39285714285714
# Average completion of my_sql course  :  27.601190476190474

# %% [markdown]
# For college_2

# %%
python2=df2['python'].mean()
my_sql2=df2['mysql'].mean()
python_en2=df2['python_en'].mean()
comp_thinking2=df2['computational_thinking'].mean()
print("Average completion of python course  : ",python2)
print("Average completion of my_sql course  : ",my_sql2)
print("Average completion of python english course  : ",python_en2)
print("Average completion of computational thinking course  : ",comp_thinking2)
# Out:
# Average completion of python course  :  8.657142857142857
# Average completion of my_sql course  :  13.657142857142857
# Average completion of python english course  :  29.65714285714286
# Average completion of computational thinking course  :  2.2

# %% [markdown]
# Combined Result

# %%
python=data1['python'].mean()
my_sql=data1['mysql'].mean()
python_en=data1['python_en'].mean()
comp_thinking=data1['computational_thinking'].mean()
print("Average completion of python course  : ",python)
print("Average completion of my_sql course  : ",my_sql)
print("Average completion of python english course  : ",python_en)
print("Average completion of computational thinking course  : ",comp_thinking)
# Out:
# Average completion of python course  :  54.35294117647059
# Average completion of my_sql course  :  23.5
# Average completion of python english course  :  29.65714285714286
# Average completion of computational thinking course  :  2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df1.sort_values(by='Rising', ascending=False).head(3)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 6   KALAIARASAN K    85.0   47.0               7750            7880
# 0       A.Dharani    82.0   20.0              24500           24500
# 53      RANJITH.R   100.0    0.0                800             800
#
#                                    Department  Rising
# 6   Electronics and Communication Engineering     130
# 0            Computer Science and Engineering       0
# 53  Electronics and Communication Engineering       0

# %%
df2.sort_values(by='Rising', ascending=False).head(3)
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N      58          0      0                       0
# 2   Ganesh Ramkumar R      -1         55     24                       6
# 18     Narasimhan Y L      -1         -1      0                       0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 2                8790           10790        Computer Science and Engineering
# 18               4800            6800        Computer Science and Engineering
#
#     Rising
# 8     3140
# 2     2000
# 18    2000

# %%
data1.sort_values(by='Rising', ascending=False,ignore_index=True).head(3)
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           shifak N    58.0    0.0               5180            8320
# 1     Narasimhan Y L    -1.0    0.0               4800            6800
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                Department  Rising  python_en  \
# 0  Electronics and Electrical Engineering    3140        0.0
# 1        Computer Science and Engineering    2000       -1.0
# 2        Computer Science and Engineering    2000       55.0
#
#    computational_thinking
# 0                     0.0
# 1                     0.0
# 2                     6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df1.sort_values(by='Previous Geekions', ascending=False,ignore_index=True).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
df2.sort_values(by='Previous Geekions', ascending=False,ignore_index=True).head(3)
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0    ASHOK KUMAR K     100          0     31                       9
# 1          Chandru       0         20      0                       0
# 2  Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2              10040           10040
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2  Electronics and Communication Engineering       0

# %%
data1.sort_values(by='Previous Geekions', ascending=False,ignore_index=True).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
data1['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
df=data1.groupby('Department')
col=(df['CodeKata Score'].agg(np.sum))
col
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

score=[320025,108335,53800]

dept=['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering']

colors = sns.color_palette('pastel')

# create pie chart using matplotlib
plt.pie(score, labels=dept, colors=colors)
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
m=data1.groupby(['Name','Department'])['CodeKata Score'].sum().sort_values(ascending=False).head(3)

# %%
m.plot.barh()

# %%
cs=data1[data1['Department']=='Computer Science and Engineering']

# %%
cs=cs.sort_values(by='CodeKata Score', ascending=False,ignore_index=True).head(3)
cs
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %%
m=cs.groupby(['Name','Department'])['CodeKata Score'].sum().sort_values(ascending=False).head(3)

# %%
m.plot.barh()

# %%
ec=data1[data1['Department']=='Electronics and Communication Engineering']

# %%
ec=ec.sort_values(by='CodeKata Score', ascending=False,ignore_index=True).head(3)

# %%
ec
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  Bodipudi Harini    -1.0   35.0              10040           10040
# 1        Gowtham R    -1.0    4.0               8650            8650
# 2    KALAIARASAN K    85.0   47.0               7750            7880
#
#                                   Department  Rising  python_en  \
# 0  Electronics and Communication Engineering       0        0.0
# 1  Electronics and Communication Engineering       0       60.0
# 2  Electronics and Communication Engineering     130        NaN
#
#    computational_thinking
# 0                    -1.0
# 1                     6.0
# 2                     NaN

# %%
n=ec.groupby(['Name','Department'])['CodeKata Score'].sum().sort_values(ascending=False).head(3)

# %%
n.plot.barh()

# %%
ee=data1[data1['Department']=='Electronics and Electrical Engineering']
ee=ee.sort_values(by='CodeKata Score', ascending=False,ignore_index=True).head(3)
ee
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
# 1      VIINU V P    -1.0   24.0               9150            9150
# 2       shifak N    58.0    0.0               5180            8320
#
#                                Department  Rising  python_en  \
# 0  Electronics and Electrical Engineering       0        0.0
# 1  Electronics and Electrical Engineering       0      100.0
# 2  Electronics and Electrical Engineering    3140        0.0
#
#    computational_thinking
# 0                     9.0
# 1                    -1.0
# 2                     0.0

# %%
p=ee.groupby(['Name','Department'])['CodeKata Score'].sum().sort_values(ascending=False).head(3)

# %%
p.plot.barh()
